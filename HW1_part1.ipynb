# %% [markdown]
# # Discussion Forum data analysis

# %%
import json
import operator
import pandas as pd

# %% [markdown]
# ## Load data

# %%
dataTitle = []
dataHouse = json.load(open('houseplantsNew.json', 'r'))
for key, value in dataHouse.items():
    dataTitle.append(value["Title"])
dataIndoor = json.load(open('IndoorGardenNew.json', 'r'))
for key, value in dataIndoor.items():
    dataTitle.append(value["Title"])
titleNum = len(dataTitle)
print("Total number of new posts:", titleNum)
# Out:
# Total number of new posts: 1759

# %% [markdown]
# ## Find out how many times participants ask for help in identifying a plant.

# %%
#TODO
possibleTitle = []
for i in range(titleNum):
    if ("what" in dataTitle[i]) or ("What" in dataTitle[i]) or ("know" in dataTitle[i]):
        possibleTitle.append(dataTitle[i])    
print("Possible titles: ", len(possibleTitle), possibleTitle)
# Out:
# Possible titles:  246 ['What’s causing yellowing on my new anthurium?', 'What is growing in my Parlour Palm pot?', 'Wow what a bargain 😍', 'Help!!! I accidentally broke my ZZ plant. I’ve struggled to grow it for an entire year. Any suggestions what I can do to save it?', 'Anyone know what this dried flower/plant is?', 'Does anyone know how to allow chrysanthemums to grow every year?', 'Help please! This was unlabeled at the store. My app identified it as “Joseph’s Coat” so I’ve been trying to care for it as such - he’s struggling though off and on so I suspected maybe that wasn’t right. So googled Joseph’s Coat and yeah that’s so not this ... anyone know it’s true name? TIA!!', 'fern kinda thing ( no clue what he is ) and hopefully it survives ...Christmas cactus is a happy girl!', "I've prune my heathers!! ✂️ I really don't know what I was doing but I did it anyway 😅 In a few months I will know if I did it well or not. (Last 📸 are the before pictures)", 'What’s happening to my ponytail palm?? I water once every 4-6 weeks and mist occasionally. Have had this for ~6 months and it started deteriorating this month', 'Anyone know what this is?', "I got this citrus tree from my friend who moved and I really don't want to kill it - what does it want? Did I over water or is there a different reason why the leaves are kinda wilty? Soil is still damp when I stick my finger in it.", 'Found this baby in the trash 😩 — what is she?', 'Hi! Can anyone tell me what kind of plant this is? The tag just says pilea.', '[ADVICE] My first ever Monstera! What should I do now ?', 'What’s wrong with my calathea jungle velvet (warscewiczii)', 'What does this plant need to be happy? My guess is more even light, but maybe a bigger pot?', 'I inherited a dumbcane but it has these little bumps along the bottom. I know nothing about plants so I’m in need of some help! Is this normal, or is it diseased? Any way to fix it?', 'what type of plant is this? at first i thought it was a schefflera but i thought scheffleras had trunks', 'Left my monstera in the car overnight in like 15 degree weather...super wilted, what to do?', 'Does anyone know what this plant is called?? I’m guessing its some type of Algaonema but not sure... thanks for your help in advance!', "I inherited these at work so I don't know what I'm doing, but the flowers are new!", 'Received this plant when my dad passed away and not sure what it is! I have two puppies and a baby and want to make sure it’s not dangerous to them if ingested.', 'Plants, books, and a doggo. What more could anyone need?', 'What kind of croton am I? Lauren’s rainbow, golden bell, mammy? Something else?', 'Rescued this overwatered spider. What should I do?', 'What’s the one plant you think everyone should own?', "My youngest Monstera, Troy, wasn't growing any fenestrations, so I tied him to a moss pole. I unknowingly tied it on a stem producing the first fenestration leaf. Once I realized it, I untied him, placed him under the humidifier in good sunlight, and the leaf is finally uncurling after a week.", 'help!! what is the name of this plant?', 'Propped Monstera in water, Saved from death, now what?', 'My plant has grown! But it’s getting a little too heavy, what can I do to help improve?', 'What on earth is this? (Philodendron Hederaceum)', 'What type of plant is this? I found it at a complex. Could it be some type of aglaonema??', 'What are these little bulbous things growing off my alocasia?', 'Cut them off? What could be wrong with this new baby?', 'What are these white spots?', 'What will happen if this leaf unfurls inside an existing fenestration?! Should I leave it alone and see what happens, or move the new growth out of the hole?', 'Help with Rananculus plants. Is it dying ? What should I do ?', 'My jade plant drops leaves often, seems like every time I water it. I thought it was root rot so I let the soil dry out. Since then I’m unsure when to water. signs of new growth but some leaves & stems feel/look soft. So ...
